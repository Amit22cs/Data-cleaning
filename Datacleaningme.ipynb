# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit22cs/Data-cleaning/blob/main/Datacleaningme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl 
import matplotlib.pyplot as plt
df=pd.read_csv('/content/pokemon.csv')
df
# Out:
#     No                       Name Type 1  Type 2  Total    HP  Attack  \
# 0    1                  Bulbasaur  Grass  Poison    318  45.0      49
# 1    2                    Ivysaur  Grass  Poison    405  60.0      62
# 2    3                   Venusaur  Grass  Poison    525  80.0      82
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80.0     100
# 4    4                 Charmander   Fire     NaN    309  39.0      52
# 5    5                 Charmeleon   Fire     NaN    405  58.0      64
# 6    6                  Charizard   Fire  Flying    534  78.0      84
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78.0     130
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78.0     104
# 9    7                   Squirtle  Water     NaN    314  44.0      48
# 10   8                  Wartortle  Water     NaN    405  59.0      63
# 11   9                  Blastoise  Water     NaN    530  79.0      83
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79.0     103
# 13  10                   Caterpie    Bug     NaN    195  45.0      30
# 14  11                    Metapod    Bug     NaN    205  50.0      20
# 15  12                 Butterfree    Bug  Flying    395  60.0      45
# 16  13                     Weedle    Bug  Poison    195   NaN      35
# 17  14                     Kakuna    Bug  Poison    205  45.0      25
# 18  15                   Beedrill    Bug  Poison    395  65.0      90
#
#     Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      49.0     65.0     65.0   45.0           1      False
# 1      63.0     80.0     80.0   60.0           1      False
# 2      83.0    100.0    100.0   80.0           1      False
# 3     123.0    122.0    120.0   80.0           1      False
# 4      43.0     60.0     50.0   65.0           1      False
# 5       NaN     80.0     65.0    NaN           1      False
# 6      78.0    109.0     85.0  100.0           1      False
# 7     111.0    130.0     85.0  100.0           1      False
# 8      78.0    159.0    115.0  100.0           1      False
# 9      65.0     50.0     64.0   43.0           1      False
# 10     80.0      NaN     80.0   58.0           1      False
# 11    100.0     85.0    105.0   78.0           1      False
# 12    120.0    135.0    115.0   78.0           1      False
# 13     35.0     20.0     20.0   45.0           1      False
# 14     55.0     25.0     25.0   30.0           1      False
# 15     50.0     90.0      NaN   70.0           1      False
# 16     30.0     20.0     20.0   50.0           1      False
# 17     50.0     25.0     25.0   35.0           1      False
# 18     40.0     45.0     80.0   75.0           1      False

# %%
df.head()
# Out:
#    No                   Name Type 1  Type 2  Total    HP  Attack  Defense  \
# 0   1              Bulbasaur  Grass  Poison    318  45.0      49     49.0
# 1   2                Ivysaur  Grass  Poison    405  60.0      62     63.0
# 2   3               Venusaur  Grass  Poison    525  80.0      82     83.0
# 3   3  VenusaurMega Venusaur  Grass  Poison    625  80.0     100    123.0
# 4   4             Charmander   Fire     NaN    309  39.0      52     43.0
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0     65.0     65.0   45.0           1      False
# 1     80.0     80.0   60.0           1      False
# 2    100.0    100.0   80.0           1      False
# 3    122.0    120.0   80.0           1      False
# 4     60.0     50.0   65.0           1      False

# %%
df.tail()
# Out:
#     No        Name Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk  \
# 14  11     Metapod    Bug     NaN    205  50.0      20     55.0     25.0
# 15  12  Butterfree    Bug  Flying    395  60.0      45     50.0     90.0
# 16  13      Weedle    Bug  Poison    195   NaN      35     30.0     20.0
# 17  14      Kakuna    Bug  Poison    205  45.0      25     50.0     25.0
# 18  15    Beedrill    Bug  Poison    395  65.0      90     40.0     45.0
#
#     Sp. Def  Speed  Generation  Legendary
# 14     25.0   30.0           1      False
# 15      NaN   70.0           1      False
# 16     20.0   50.0           1      False
# 17     25.0   35.0           1      False
# 18     80.0   75.0           1      False

# %%
df.describe()
# Out:
#               No       Total         HP      Attack     Defense     Sp. Atk  \
# count  19.000000   19.000000  18.000000   19.000000   18.000000   18.000000
# mean    7.578947  413.578947  62.333333   66.789474   69.611111   77.777778
# std     4.154192  156.815644  15.142461   30.578822   28.981006   42.569743
# min     1.000000  195.000000  39.000000   20.000000   30.000000   20.000000
# 25%     4.500000  311.500000  46.250000   46.500000   49.250000   46.250000
# 50%     7.000000  405.000000  60.000000   63.000000   64.000000   80.000000
# 75%    10.500000  532.000000  78.000000   87.000000   82.250000  106.750000
# max    15.000000  634.000000  80.000000  130.000000  123.000000  159.000000
#
#           Sp. Def       Speed  Generation
# count   18.000000   18.000000        19.0
# mean    72.166667   66.222222         1.0
# std     33.322400   22.054893         0.0
# min     20.000000   30.000000         1.0
# 25%     53.500000   46.250000         1.0
# 50%     80.000000   67.500000         1.0
# 75%     96.250000   79.500000         1.0
# max    120.000000  100.000000         1.0

# %%
df.count()
# Out:
# No            19
# Name          19
# Type 1        19
# Type 2        11
# Total         19
# HP            18
# Attack        19
# Defense       18
# Sp. Atk       18
# Sp. Def       18
# Speed         18
# Generation    19
# Legendary     19
# dtype: int64

# %%
df.isna().sum()
# Out:
# No            0
# Name          0
# Type 1        0
# Type 2        8
# Total         0
# HP            1
# Attack        0
# Defense       1
# Sp. Atk       1
# Sp. Def       1
# Speed         1
# Generation    0
# Legendary     0
# dtype: int64

# %%
df=df.fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# No            0
# Name          0
# Type 1        0
# Type 2        0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
df.shape
# Out:
# (19, 13)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# dtype: bool

# %%
a=df.drop_duplicates()

# %%
df.drop(['Generation'],axis=1)
# Out:
#     No                       Name Type 1  Type 2  Total    HP  Attack  \
# 0    1                  Bulbasaur  Grass  Poison    318  45.0      49
# 1    2                    Ivysaur  Grass  Poison    405  60.0      62
# 2    3                   Venusaur  Grass  Poison    525  80.0      82
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80.0     100
# 4    4                 Charmander   Fire  Flying    309  39.0      52
# 5    5                 Charmeleon   Fire  Flying    405  58.0      64
# 6    6                  Charizard   Fire  Flying    534  78.0      84
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78.0     130
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78.0     104
# 9    7                   Squirtle  Water  Flying    314  44.0      48
# 10   8                  Wartortle  Water  Flying    405  59.0      63
# 11   9                  Blastoise  Water  Flying    530  79.0      83
# 12   9    BlastoiseMega Blastoise  Water  Flying    630  79.0     103
# 13  10                   Caterpie    Bug  Flying    195  45.0      30
# 14  11                    Metapod    Bug  Flying    205  50.0      20
# 15  12                 Butterfree    Bug  Flying    395  60.0      45
# 16  13                     Weedle    Bug  Poison    195  45.0      35
# 17  14                     Kakuna    Bug  Poison    205  45.0      25
# 18  15                   Beedrill    Bug  Poison    395  65.0      90
#
#     Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 0      49.0     65.0     65.0   45.0      False
# 1      63.0     80.0     80.0   60.0      False
# 2      83.0    100.0    100.0   80.0      False
# 3     123.0    122.0    120.0   80.0      False
# 4      43.0     60.0     50.0   65.0      False
# 5      78.0     80.0     65.0  100.0      False
# 6      78.0    109.0     85.0  100.0      False
# 7     111.0    130.0     85.0  100.0      False
# 8      78.0    159.0    115.0  100.0      False
# 9      65.0     50.0     64.0   43.0      False
# 10     80.0     85.0     80.0   58.0      False
# 11    100.0     85.0    105.0   78.0      False
# 12    120.0    135.0    115.0   78.0      False
# 13     35.0     20.0     20.0   45.0      False
# 14     55.0     25.0     25.0   30.0      False
# 15     50.0     90.0     20.0   70.0      False
# 16     30.0     20.0     20.0   50.0      False
# 17     50.0     25.0     25.0   35.0      False
# 18     40.0     45.0     80.0   75.0      False

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
(sns.get_dataset_names()) 
ff=sns.load_dataset('titanic') 
(ff.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ff.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
ff.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
ff.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
ff.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [784 rows x 15 columns]

# %%
import matplotlib as mpl 
import matplotlib.pyplot as plt

x=('Atk')
y=('Speed')
plt.plot('Sp. Atk	','Speed',Data=a)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-7451ae6bcd30> in <cell line: 6>()
#       4 x=('Atk')
#       5 y=('Speed')
# ----> 6 plt.plot('Sp. Atk       ','Speed',Data=a)
#       7 plt.show()
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     452             # xy is tup with fmt stripped (could still be (y,) only)
#     453             *xy, fmt = tup
# --> 454             linestyle, marker, color = _process_plot_format(
#     455                 fmt, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     456         elif len(tup) == 3:
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_base.py in _process_plot_format(fmt, ambiguous_fmt_datakey)
#     196             i += 2
#     197         else:
# --> 198             raise ValueError(
#     199                 errfmt.format(fmt, f"unrecognized character {c!r}"))
#     200
#
# ValueError: 'Speed' is not a valid format string (unrecognized character 'S')
